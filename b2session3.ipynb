# %%
#Variable~building blocks of memory

student_name ="Riya"
student_age=20

print(student_name)
print(student_age)
# Out:
# Riya
# 20

# %%
#assignment operator ~it assigns value
cllg_name="GLA"

# %%
#data types
# String = Text
# Integer = Whole Number
# Float = Decimal Number
# Boolean = True/False
# Complex = Complex Number

#small snippets have these data types
student_name = "Riya"
student_age = 20
attendance = 85.5
is_present = True
complex_num = 3 + 4j

print(student_name)
print(student_age)
print(attendance)
print(is_present)
print(complex_num)
# Out:
# Riya
# 20
# 85.5
# True
# (3+4j)

# %%
#list
#CREATE A LIST OF 5 SUBJECTS AND PRINT THE 1ST AND LAST ELEMENT


s=['maths','english','hindi','science','gk']
print(s[0],s[-1])
# Out:
# maths gk

# %%
#CODE FOR PASS OR FAIL, PASS BE 40 OR ABOVE RUN THIS CODE ON A LIST OF STUDENT OF 5 STUDENTS
students = [ "Abhi","Raghav", "Karan", "Radha", "Rahul"]
marks = [90, 65, 78, 15, 25]
for i in range(len(marks) - 1):
  if marks[i] > 40:
    print(students[i] + " - " +  "PASS")
  else:
    print(students[i] + " - " + "FAIL")
# Out:
# Abhi - PASS
# Raghav - PASS
# Karan - PASS
# Radha - FAIL

# %%
# CODE TO CHECK WHETHER NUMBER IS POSITIVE, NEGATIVE OR ZERO IN A GIVEN LIST OF NUMBER
numbers = [-80, 675, 0, -30, 95]
for num in numbers:
  if num > 0:
    print(num, "is positive")
  elif num < 0:
    print(num, "is negative")
  else:
    print(num, "is zero")
# Out:
# -80 is negative
# 675 is positive
# 0 is zero
# -30 is negative
# 95 is positive

# %%
# STUDENT NAME AS INPUT

# BASED ON THEIR MARKS YOU HAVE TO CONSIDER A PRINT STATEMENT FOR "PERFORMENCE" MARKS IS MORE THAN 75 THEN PERFORMANCE IS STRONG MARKS IS EQUAL TO OR GREATER THAN 40, PERFORMANCE SHOULD PRINT NEED TO IMPORVEMENT LESS 20 THEN PRINT FAIL ,REPEAT CLASS

# ATENDANCE 75- WARNING LOW ATTENDANCE STUDY_HOUR LESS THAN 4 PRINT SHOULD COME WARNING NEEDS MORE STUDY TIME



students = [
    {
        "name": "Kriti",
        "study_hours": 7,
        "attendance": 88,
        "marks": 92
    },
    {
        "name": "Pranav",
        "study_hours": 3,
        "attendance": 72,
        "marks": 68
    },
    {
        "name": "Riya",
        "study_hours": 2,
        "attendance": 65,
        "marks": 15
    },
    {
        "name": "Amar",
        "study_hours": 5,
        "attendance": 90,
        "marks": 80
    },
    {
        "name": "Nehal",
        "study_hours": 1,
        "attendance": 55,
        "marks": 35
    }
]

search = input("Enter the name of the student: ")

for student in students:
    if student["name"] == search:
        marks = student["marks"]

        print("Marks:", student["marks"])

        if marks > 75:
            print("Performance is Strong")

        elif marks >= 40:
            print("Performance needs improvement")

        else:
            print("Fail - Repeat Class")

        if student["attendance"] < 75:
            print("Warning: Low Attendance")

        if student["study_hours"] < 4:
            print("Warning: Need more study time")
# Out:
# Enter the name of the student: Nehal
# Marks: 35
# Fail - Repeat Class
# Warning: Low Attendance
# Warning: Need more study time

# %%
# Find suspicious transactions.
# If amount is greater than 5000 and payment method is "Gift Card",
# store the transaction ID in flagged_transactions.
# Print the final list of flagged transactions.


transactions = [
    {"transaction_id": "TX101", "amount": 6200, "method": "Credit Card"},
    {"transaction_id": "TX102", "amount": 5500, "method": "Gift Card"},
    {"transaction_id": "TX103", "amount": 1200, "method": "Gift Card"},
    {"transaction_id": "TX104", "amount": 8000, "method": "Gift Card"},
    {"transaction_id": "TX105", "amount": 450, "method": "PayPal"}
]

flagged_transactions = []

for t in transactions:
    if t["amount"] > 5000 and t["method"] == "Gift Card":
        flagged_transactions.append(t["transaction_id"])

print(flagged_transactions)
# Out:
# ['TX102', 'TX104']
